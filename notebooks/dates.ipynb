# %%
import csv
import pandas as pd
import numpy as np
import operator

# %%
# Read airquality data
df = pd.read_csv('../data/final_data.csv', parse_dates=['date'])

# %%
df.head()
# Out:
#    Unnamed: 0       date county  acresBurned  numFires  YTDRain  dailyRain  \
# 0           0 2014-01-01  Butte         60.0       1.0      NaN        NaN
# 1           1 2014-01-01  Butte         60.0       1.0      NaN        NaN
# 2           2 2014-01-01  Butte         60.0       1.0      NaN        NaN
# 3           3 2014-01-01  Butte         60.0       1.0      NaN        NaN
# 4           4 2014-01-01  Butte         60.0       1.0      NaN        NaN
#
#         y_aq      x_aq  value_aq      @sin      @cos    @angle  position  \
# 0   0.999852  0.017213       1.0  0.017213  0.999852  0.986301       1.0
# 1   0.999852  0.017213       1.0  0.017213  0.999852  0.986301       1.0
# 2   0.999852  0.017213       1.0  0.017213  0.999852  0.986301       1.0
# 3  39.727446  0.683944      59.6  0.017213  0.999852  0.986301       0.0
# 4  19.863723  0.341972      59.6  0.017213  0.999852  0.986301       0.0
#
#    airQuality layer  maxTemp  minTemp
# ...

# %%
df['date']
# Out:
# 0         2014-01-01
# 1         2014-01-01
# 2         2014-01-01
# 3         2014-01-01
# 4         2014-01-01
#              ...
# 2606946   2020-12-06
# 2606947   2020-12-07
# 2606948   2020-12-08
# 2606949   2020-12-09
# 2606950   2020-12-10
# Name: date, Length: 2606951, dtype: datetime64[ns]

# %%
# Write resulting data to csv
df.to_csv('../data/final_data_dates.csv', index=False)
